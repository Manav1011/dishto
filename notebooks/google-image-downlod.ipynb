# %%
from icrawler.builtin import GoogleImageCrawler

google_crawler = GoogleImageCrawler(storage={'root_dir': 'punjabi_food'})
google_crawler.crawl(keyword='Punjabi Food Category Display Image', max_num=10,  filters={
        'size': 'large'  # Options: large, medium, icon
    })
# Out:
# 2025-07-08 22:31:56,996 - INFO - icrawler.crawler - start crawling...
# 2025-07-08 22:31:56,997 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-07-08 22:31:56,998 - INFO - feeder - thread feeder-001 exit
# 2025-07-08 22:31:56,999 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-07-08 22:31:57,000 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2025-07-08 22:31:58,227 - INFO - parser - parsing result page https://www.google.com/search?q=Punjabi+Food+Category+Display+Image&ijn=0&start=0&tbs=isz%3Al&tbm=isch
# 2025-07-08 22:32:00,284 - INFO - downloader - image #1	https://cookwithrenu.com/wp-content/uploads/2020/09/Punjabi-Thali_Featured-Image.jpg
# 2025-07-08 22:32:00,490 - INFO - downloader - image #2	https://m.economictimes.com/thumb/msid-71121981,width-1200,height-900,resizemode-4,imgsize-810723/butter-chicken-1.jpg
# ...
